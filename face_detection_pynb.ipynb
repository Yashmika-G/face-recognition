# %%
import cv2

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml -O /content/default.xml1
# Out:
# --2024-04-16 13:45:32--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘/content/default.xml1’
#
# /content/default.xm 100%[===================>] 908.33K  --.-KB/s    in 0.05s
#
# 2024-04-16 13:45:32 (18.3 MB/s) - ‘/content/default.xml1’ saved [930127/930127]

# %%
facedetect=cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')

# %%
img=cv2.imread('/content/05-12-21-happy-people.jpg')

# %%
# Display the image using Google Colab's cv2_imshow function
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1400x880>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
print(gray.shape)
# Out:
# (880, 1400)

# %%
# !pip install opencv-python

# %%
import os

if not os.path.isfile('haarcascade_frontalface_default.xml'):
    # !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2024-04-16 13:47:36--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.05s
#
# 2024-04-16 13:47:36 (19.2 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [930127/930127]

# %%
face = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
face = face.detectMultiScale(gray, 1.7, 2)

# %%
for(x,y,w,h) in face:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),5)

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=1400x880>
# -1
